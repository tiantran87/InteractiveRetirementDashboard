# %%
# Initial imports
import warnings
warnings.filterwarnings('ignore')
import os
import requests
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from MCForecastTools import MCSimulation
import json
# Initialize the Panel Extensions (for Plotly)
import panel as pn
pn.extension('plotly')
import plotly.express as px
import hvplot.pandas
import matplotlib.pyplot as plt
import os
from pathlib import Path
from dotenv import load_dotenv
import ipywidgets as widgets
from IPython.display import display
# %matplotlib inline
#!pip install yfinance
import yfinance as yf
#!pip install mplfinance
import mplfinance as mpf
import datetime as dt
pn.extension()
# Load .env enviroment variables
load_dotenv()
# Out:
# True

# %%
# Define Parameters

range_of_cryptos = ["BTC-USD", "ETH-USD", "BNB-USD", "ADA-USD", "DOGE-USD", "XRP-USD", "LINK-USD" , "THETA-USD", "LTC-USD", "XLM-USD"]
range_of_stocks = ["AMZN", "TSLA", "NEO", "AAPL", "NVDA", "BABA", "NFLX", "DIS", "NKE"]

# Define Functions

#download crypto data and stock data for 5 years
def download_cryptos_data(event):
    df = yf.download(range_of_cryptos, period = "3y", group_by = 'ticker', threads = True, progress=False)
    df = df.dropna().copy()
    return df

def download_stocks_data(event):
    df = yf.download(range_of_stocks, period = "3y", group_by = 'ticker', threads = True, progress=False)
    df = df.dropna().copy()
    return df



def daily_return_plot(df):
    df = df.dropna().copy()    
    plot = df['Close'].pct_change().hvplot.line(x="Date", rot=45).opts(yformatter="%.0f", xlabel="Time", ylabel="Value", title="Daily Return", color="Red")
    return plot

def cumulative_return_plot(df):
    cumulative_returns = (1 + df['Close'].pct_change()).cumprod()
    plot = cumulative_returns.hvplot.line(x="Date", rot=45).opts(yformatter="%.0f", xlabel="Time", ylabel="Value", title="Cumulative Return", color="Blue")
    return plot


def create_input():
    # Fetch initial data:
    crypto_df = download_cryptos_data('random')
    stock_df = download_stocks_data('random')
    # Input widgets
    crypto_button = pn.widgets.Button(name='Update Crypto Data', button_type='primary')
    stock_button = pn.widgets.Button(name='Update Stock Data', button_type='primary')
    crypto_df = crypto_button.on_click(download_cryptos_data)
    stock_df = stock_button.on_click(download_stocks_data)
    buton_row = pn.Row(crypto_button, stock_button)
    
    crypto_ticker = pn.widgets.Select(name='Crypto Tickes', options=range_of_cryptos)
    crypto_year_slider = pn.widgets.IntSlider(name='Years of Crypto Data', start=0, end=3, step=1, value=1)
    stock_ticker = pn.widgets.Select(name='Stock Tickers', options=range_of_stocks) 
    stock_year_slider = pn.widgets.IntSlider(name='Years of Stock Data', start=0, end=3, step=1, value=1)
        
    crypto_input = pn.Column(crypto_ticker, crypto_year_slider)
    stock_input = pn.Column(stock_ticker, stock_year_slider)
    parameter_row = pn.Row(crypto_input, stock_input)
    
    user_input_data = pn.Column(buton_row, parameter_row)
    return user_input_data


#-----------------------------------------------------------------------------

# CALCULATE candle plot"
def candle_volume_plot(df):
    plot = mpf.plot(df,type='candle',mav=(3,6,9),volume=True, title='dissa candle plot')
    return plot

# %%
# Create a Title for the Dashboard
create_input()
# Out:
# Column
#     [0] Row
#         [0] Button(button_type='primary', name='Update Crypto Data')
#         [1] Button(button_type='primary', name='Update Stock Data')
#     [1] Row
#         [0] Column
#             [0] Select(name='Crypto Tickes', options=['BTC-USD', 'ETH-USD', ...], value='BTC-USD')
#             [1] IntSlider(end=3, name='Years of Crypto Data', value=1)
#         [1] Column
#             [0] Select(name='Stock Tickers', options=['AMZN', 'TSLA', ...], value='AMZN')
#             [1] IntSlider(end=3, name='Years of Stock Data', value=1)

# %%
crypto_df = download_cryptos_data('a')
#crypto_df['ADA-USD'].head()

candle_volume_plot(crypto_df['ADA-USD'])

# %%
dashboard.servable()

# %%
range_of_cryptos = ["BTC", "ETH", "BNB", "ADA", "DOGE", "XRP", "LINK" , "THETA", "LTC", "XLM"]
range_of_stocks = ["AMZN", "TSLA", "NEO", "AAPL", "XPENG", "BABA", "SNPWR", "NFLX", "DIS", "NIKE"]

# Declare Witget input elements
year_slider = widgets.IntSlider(min=0, max=3, step=1, description='Year of data:', value=3)
dropdown_crypto = widgets.Dropdown(options = range_of_cryptos)
dropdown_stock = widgets.Dropdown(options = range_of_stocks)


input_crypto_box = widgets.VBox([dropdown_crypto, year_slider])
input_stock_box = widgets.VBox([dropdown_stock, year_slider])

input_box = widgets.HBox([input_crypto_box, input_stock_box])

#output_crypto_box = widgets.VBox([dropdown_crypto.value])
#output_stock_box = widgets.VBox([dropdown_stock, year_slider])



input_box


#output_crypto_box
#output_box = widgets.HBox([output_crypto_box, output_stock_box])
# Out:
# HBox(children=(VBox(children=(Dropdown(options=('BTC', 'ETH', 'BNB', 'ADA', 'DOGE', 'XRP', 'LINK', 'THETA', 'L…

# %%
text = pn.widgets.TextInput(value='Ready')
button = pn.widgets.Button(name='Click me', button_type='primary')
def b(event):
    text.value = 'Clicked {0} times'.format(button.clicks)
    
button.on_click(b)
pn.Row(button, text)
# Out:
# Row
#     [0] Button(button_type='primary', name='Click me')
#     [1] TextInput(value='Ready')

# %%
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.7a17-py3-none-any.whl (62 kB)
# Requirement already satisfied: matplotlib in c:\users\tuana\anaconda3\envs\pyvizenv\lib\site-packages (from mplfinance) (3.4.2)
# Requirement already satisfied: pandas in c:\users\tuana\anaconda3\envs\pyvizenv\lib\site-packages (from mplfinance) (1.1.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tuana\anaconda3\envs\pyvizenv\lib\site-packages (from matplotlib->mplfinance) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tuana\anaconda3\envs\pyvizenv\lib\site-packages (from matplotlib->mplfinance) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tuana\anaconda3\envs\pyvizenv\lib\site-packages (from matplotlib->mplfinance) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tuana\anaconda3\envs\pyvizenv\lib\site-packages (from matplotlib->mplfinance) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tuana\anaconda3\envs\pyvizenv\lib\site-packages (from matplotlib->mplfinance) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\tuana\anaconda3\envs\pyvizenv\lib\site-packages (from matplotlib->mplfinance) (1.16.5)
# Requirement already satisfied: six in c:\users\tuana\anaconda3\envs\pyvizenv\lib\site-packages (from cycler>=0.10->matplotlib->mplfinance) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\tuana\anaconda3\envs\pyvizenv\lib\site-packages (from pandas->mplfinance) (2021.1)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.7a17
